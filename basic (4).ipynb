# %%
a=int(input())

b=int(input())

if a%5==0:

    if a<b:

        c=b-a-.5

        d=format(c,".2f")

        print(d)

    elif a>b:

        e=format(b,".2f")

        print(e)

elif a%5!=0:

        f=format(b,".2f")

        print(f)
# Out:
# 5
# 7
# 1.50
