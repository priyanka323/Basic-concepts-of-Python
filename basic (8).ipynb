# %%
    arr=[]
    arr.insert(0,5)
    arr.insert(1,10)
    arr.insert(0,6)
    print(arr)
    arr.remove(6)
    arr.append(9)
    arr.append(1)
    print(sorted(set(arr)))
    arr.pop(3)
    arr.sort(reverse=True)
    print(arr)
# Out:
# [6, 5, 10]
# [1, 5, 9, 10]
# [10, 9, 5]

# %% [markdown]
# Maalo ki maine ye inout dia
#
# 3
# Append 5
# Pop
# Print

# %%
a=[3,8,6,7]
print(sorted(set(a)))
# Out:
# [3, 6, 7, 8]
