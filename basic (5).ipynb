# %%
a = "hello, world!"
print(a)
# Out:
# hello, world!

# %%
n=int(input())

# %%
n=int(input())
if n%2!=0:
    print("Weird")
else:
    if n in range(2,6):
        print("not weird")
    elif n in range(6,21):
        print("weird")
    elif n>20:
        print("not wierd")
# Out:
# 44
# not wierd

# %%
a=int(input())
b=int(input())
print("sum of numbers",a+b)
print("subtraction of numbers",a-b)
print("product of numbers",a*b)
# Out:
# 5
# 3
# sum of numbers 8
# subtraction of numbers 2
# product of numbers 15

# %%
a=int(input())
b=int(input())
print(a\\b)
print(a\b)
# Out:
#   File "<ipython-input-11-2398237cb7f6>", line 3
#     print(a\\b)
#                ^
# SyntaxError: unexpected character after line continuation character

# %%
a=int(input())
b=int(input())
x = a \\ b
y=a\b
print(x)
print(y)

# %%
print (5//2)
print(5%2)
# Out:
# 2
# 1

# %%
a=int(input())
b=int(input())
print(a//b)
print(floata/b)

# %%
n=int(input())
for i in range(n):
 print(i*i)
# Out:
# 5
# 0
# 1
# 4
# 9
# 16

# %%
n=int(input())
if ((n%400==0) or (n%4==0) and (n%100==0)):
  print("true")
else:
  print("false")
# Out:
# 2000
# true

# %%
n=int(input())
sum=0
for i in range(1,n+1):
  sum=sum+1
  print(sum,end='')
# Out:
# 6
# 123456

# %%
if __na__ == '__main__':
    for i in range(int(raw_input())):
        na = raw_input()
        score = float(raw_input())
        s_list.append([na,score])
        sec_highest=sorted(set[name for na, score in s_list])[1]
        print('\n'.join(sorted([name for na, score for s_list if score==sec_highest])))
# Out:
#   File "<ipython-input-53-d1cb8291fc11>", line 6
#     sec_highest=sorted(set[name for na, score in s_list])[1]
#                                   ^
# SyntaxError: invalid syntax

# %%
score_list = []
for i in range(int(input())):
name=input()
score = float(input())
score_list.append([name, score])
second_highest = sorted(set([name for name, score in score_list]))[1]
print('\n'.join(sorted([name for name, score in score_list if score == second_highest])))
# Out:
#   File "<ipython-input-59-8d5f1ad957b6>", line 3
#     name=input()
#        ^
# IndentationError: expected an indented block

# %%
score_list = []
for i in range(int(input())):
  name=input()
  score=float(input())
  score_list.append([name, score])
  second_highest = sorted(set([name for name, score in score_list]))[1]
  print(second_highest)
# Out:
# ram
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-a31ccafe4b8b> in <module>()
#       1 score_list = []
# ----> 2 for i in range(int(input())):
#       3   name=input()
#       4   score=float(input())
#       5   score_list.append([name, score])
#
# ValueError: invalid literal for int() with base 10: 'ram'

# %%
a="first_name"=str(input())
b="last_name"=str(input())
c = a+b
print("Hello" c "! you are just delved into python")
# Out:
#   File "<ipython-input-71-04a73bcff591>", line 4
#     print("Hello" c "! you are just delved into python")
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# def print_full_name(first, last):
#     last=last+'!'
#     print("Hello",first,last,"You are just delved into python")

# %%
a = "priyanka"
print(string.uppercase(a))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-60be831e58b8> in <module>()
#       1 a = "priyanka"
# ----> 2 print(string.uppercase(a))
#
# NameError: name 'string' is not defined

# %%
def split_and_join(line):
  line="this is string"
  line= line.split("")
  print(line)
  return "-".join(line)
    # write your code here

# %%
def print_full_name(first, last):
    last = last+'!'
    print("Hello", first, last, "You are just delved into python")
