# %%
a= "hello"
b= "guru99"
c="software testing"
print("b[0]:",b[0])
print(a[4])
print("c[1:5]:",c[1:5])
# Out:
# b[0]: g
# o
# c[1:5]: oftw

# %%
x = "aaaaaaaaa"
a not in x
# Out:
# True

# %%
4**5
# Out:
# 1024

# %%
name="guru"
num=99
print(%d%s%)

# %%
oldstring

# %%
a= "Python is Programing Language"
print(a.upper())
print(a.capitalize())
print(a.lower())
# Out:
# PYTHON IS PROGRAMING LANGUAGE
# Python is programing language
# python is programing language

# %%
a = "12345"
print(reversed(a))

# %%
word = "gugu99 career guru99"
print(word.split(''))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-a03528c1e812> in <module>()
#       1 word = "gugu99 career guru99"
# ----> 2 print(word.split(''))
#
# ValueError: empty separator

# %%
x="guru99"
y=x.replace('guru99','python')
print(y)
# Out:
# python

# %%
print(":".join("Python"))
# Out:
# P:y:t:h:o:n

# %%
a ="hgjsk"
after_strip=a.strip([h])
print(after_strip)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-5f3581345a4e> in <module>()
#       1 a ="hgjsk"
# ----> 2 after_strip=a.strip([h])
#       3 print(after_strip)
#
# NameError: name 'h' is not defined

# %%
a=['x','b','c']
a.reverse()
print(a)
print(a[0])
a.reverse()
print(a[0])
# Out:
# ['c', 'b', 'x']
# c
# x

# %%
txt = "     banana     "

x = txt.strip()

print("of all fruits", x, "is my favorite")

# %%
txt = "banana, apple, ornage"
x = txt.strip()
print("of all fruits", x, "are my fav.")

# %%
x= "12345"
print(" ".join(reversed(x)))

# %%
word = "gurucareergurn"
print(word.split(" "))

# %%
str = "welocme to back"
print(str.strip("back "))

# %%
str ="hello world"
str_count = str.count('0')

# %%
x = "c(=n)(n)N.c(=o)(o)o"
p = x.find("(o")
print(p)
s = x.split("n")
print(s)

# %%
string.find(value,start,end)

# %% [markdown]
# set &dictionary

# %% [markdown]
# set repetition not alowed set and dict are same as data not repeated

# %%
basket=['apple','pear', 'banana','apple']
fruits = set(basket)
print(fruits)
type(fruits)
# Out:
# {'banana', 'pear', 'apple'}
# set

# %%
a = set("acads")
b = set('institue')
A = a.split(" ,0")
B = b.split(",")
print(A|B)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-210d50ee7d01> in <module>()
#       1 a = set("acads")
#       2 b = set('institue')
# ----> 3 A = a.split(" , ")
#       4 B = b.split(",")
#       5 print(A|B)
#
# AttributeError: 'set' object has no attribute 'split'

# %%
d = {1:'hello',2:'ha',3:'del'}
a = d.keys()
print(a)
print(d.get(6, 5))

print(d["0"])
# Out:
# dict_keys([1, 2, 3])
# 5
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-fd211ae45353> in <module>()
#       4 print(d.get(6, 5))
#       5
# ----> 6 print(d["0"])
#
# KeyError: '0'
