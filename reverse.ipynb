# %%
arr1 = [1, 2, 3, 4, 5]
arr2 = [3, 4, 6, 2]
print(Reverse(arr1))
print(Reverse(arr2))

# %%
def Reverse(lst):
    lst.reverse()
    return lst
    lst = [10, 11, 12, 13, 14, 15]
print(Reverse(lst))

# %%
# Reversing a list using reversed()
def Reverse(lst):
    return [ele for ele in reversed(lst)]
      
# Driver Code
lst = [10, 11, 12, 13, 14, 15]
lst1 = [2, 3, 23, 5]
print(Reverse(lst))
print(Reverse(lst1))
for range(lst.length):
# Out:
#   File "<ipython-input-12-c5991f90c0b4>", line 10
#     print(Reverse(lst[]) + Reverse(lst2)[])
#                       ^
# SyntaxError: invalid syntax
