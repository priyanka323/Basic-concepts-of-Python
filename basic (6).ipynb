# %%
def printname(n):
  print("pri")
  print("rani")
  n=n-1
  if(n>0):
    printname(n)
  

printname(8)
# Out:
# pri
# rani
# pri
# rani
# pri
# rani
# pri
# rani
# pri
# rani
# pri
# rani
# pri
# rani
# pri
# rani

# %%
5!=5x4x3x2x1
0!=1

# %%
def factorial(n):
  if(n==0):
    return 1
    
  return n * factorial(n-1)  
  
  
ans=  factorial(8)
print(ans)
# Out:
# 40320
