# %%
"national" in "international"
# Out:
# True

# %%
for i in range (1,20):
if i % 5 = 0:
  continue
  print(i)
  print("loop over")

# %%
i = 1
while i <= 10
if i%2==0:
  continue
  print(i, end='')
  i = i+1
