# %%
print("Priyanka")

# %%
list(range(10))

# %%
n= int(input())
sum = 0
for i in range(n+1):
  sum = sum+i
  print(sum)
# Out:
# 5
# 0
# 1
# 3
# 6
# 10
# 15

# %%
n = int(input())
for i in range(n):
  if i%2==0:
    print(i)
# Out:
# 5
# 0
# 2
# 4

# %%
n = int(input())
for i in range(n):
  if i%2!=0:
    print(i)
# Out:
# 9
# 1
# 3
# 5
# 7

# %%
n= int(input())
isprime = True
for i in range(2, n):
  if(n%i==0):
    isprime = False
    print(n, "is not prime")
    break
if(isprime):
print(n, "in prime")
# Out:
# 5
# 5 in prime

# %%
n = int(input())
for i in range(2, n):
  if(n%i==0):
    print("not prime")
  else:
    print("prime")

# %%
for i in range(10):
  if(i>5):
    break
    print(i)

# %%
#doubt but wrong tjis
n = int(input())
for i in range(2, n):
  if(n%i==0):
    print("not prime")
  else:
    print("prime")
    break
# Out:
# 6
# not prime
# not prime
# prime

# %%
#list
myFavColors = ["red", "blue", "black", "pink", "white"]
myFavFood = ["cinese", "itlaian", "indian"]
print(myFavColors)
print(myFavFood)

# %%
for color in myFavColors:
  print(color.upper)
