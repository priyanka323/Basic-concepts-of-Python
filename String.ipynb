# %%
txt = "     banana     "

x = txt.strip()

print("of all fruits", x, "is my favorite")
# Out:
# of all fruits banana is my favorite

# %%
txt = "banana, apple, ornage"
x = txt.strip()
print("of all fruits", x, "are my fav.")
# Out:
# of all fruits banana, apple, ornage are my fav.

# %%
x= "12345"
print(" ".join(reversed(x)))
# Out:
# 5 4 3 2 1

# %%
word = "gurucareergurn"
print(word.split(" "))
# Out:
# ['gurucareergurn']

# %%
str = "welocme to back"
print(str.strip("back "))
# Out:
# welocme to

# %%
str ="hello world"
str_count = str.count('0')

# %%
x = "c(=n)(n)N.c(=o)(o)o"
p = x.find("(o")
print(p)
s = x.split("n")
print(s)
# Out:
# 15
# ['c(=', ')(', ')N.c(=o)(o)o']
